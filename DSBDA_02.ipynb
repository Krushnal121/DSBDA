# %% [markdown]
# <a href="https://colab.research.google.com/github/Krushnal121/DSBDA/blob/main/DSBDA_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("StudentsPerformance.csv")

# %%
df.head()
# Out:
#    PRN Gender  Physics  Chemistry  Biology
# 0    1      F       72         72       74
# 1    2      F       69         90       88
# 2    3      F       90         95       93
# 3    4      M       47         57       44
# 4    5      M       76         78       75
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['PRN'].plot(kind='hist', bins=20, title='PRN')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Physics'].plot(kind='hist', bins=20, title='Physics')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Chemistry'].plot(kind='hist', bins=20, title='Chemistry')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['Biology'].plot(kind='hist', bins=20, title='Biology')
# ...

# %%
from matplotlib import pyplot as plt
_df_13['Physics'].plot(kind='line', figsize=(8, 4), title='Physics')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_12['PRN'].plot(kind='line', figsize=(8, 4), title='PRN')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_0['PRN'].plot(kind='hist', bins=20, title='PRN')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PRN        1000 non-null   int64
#  1   Gender     1000 non-null   object
#  2   Physics    1000 non-null   int64
#  3   Chemistry  1000 non-null   int64
#  4   Biology    1000 non-null   int64
# dtypes: int64(4), object(1)
# memory usage: 39.2+ KB

# %%
df.isnull().sum()
# Out:
# PRN          0
# Gender       0
# Physics      0
# Chemistry    0
# Biology      0
# dtype: int64

# %%
numeric_variable=df.columns[df.dtypes!='O']

# %%
numeric_variable
# Out:
# Index(['PRN', 'Physics', 'Chemistry', 'Biology'], dtype='object')

# %%
categorical_variable=df.columns[df.dtypes=='O']

# %%
categorical_variable
# Out:
# Index(['Gender'], dtype='object')

# %%
plt.figure(figsize=(8,7))
x=0
for i in numeric_variable:
  sns.histplot(data=df,x=i,kde=True)
  plt.show()

# %%
plt.figure(figsize=(8,7))
x=0
for i in numeric_variable:
  df.boxplot(i)
  plt.show()
